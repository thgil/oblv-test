# %%
# %%bash
#
# wget https://api.oblivious.ai/oblv-ccli/0.4.0/oblv-ccli-0.4.0-x86_64-unknown-linux-musl.tar.gz
#
# tar xvf oblv-ccli-0.4.0-x86_64-unknown-linux-musl.tar.gz
#
# chmod +x $(pwd)/oblv
#
# sudo ln -s $(pwd)/oblv /usr/local/bin/oblv
# Out:
# --2023-05-22 04:30:59--  https://api.oblivious.ai/oblv-ccli/0.4.0/oblv-ccli-0.4.0-x86_64-unknown-linux-musl.tar.gz
# Resolving api.oblivious.ai (api.oblivious.ai)... 54.77.73.183, 54.78.188.70
# Connecting to api.oblivious.ai (api.oblivious.ai)|54.77.73.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10229760 (9,8M) [application/x-gzip]
# Saving to: ‘oblv-ccli-0.4.0-x86_64-unknown-linux-musl.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  0%  943K 11s
#     50K .......... .......... .......... .......... ..........  1% 1,57M 8s
#    100K .......... .......... .......... .......... ..........  1% 1,07M 9s
#    150K .......... .......... .......... .......... ..........  2% 1,99M 8s
#    200K .......... .......... .......... .......... ..........  2% 1,26M 8s
#    250K .......... .......... .......... .......... ..........  3% 1,19M 8s
#    300K .......... .......... .......... .......... ..........  3% 1,33M 7s
# ...

# %%
# !oblv keygen --key-name alice --output /content/
# Out:
# bash: line 2: ./oblv: Bad CPU type in executable
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\n./oblv keygen\n')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2422, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2420 with self.builtin_trap:
#    2421     args = (magic_arg_s, cell)
# -> 2422     result = fn(*args, **kwargs)
#    2423 return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
# ...
